# %%
import pandas as pd

# %%
api_datasets: pd.DataFrame = pd.read_csv('../data/external/')

# %%
dipres_datasets = api_datasets[api_datasets['Organization_title'] == 'Dirección de Presupuestos']

# %%
dipres_datasets

# %%
dipres_dic = pd.read_csv(dipres_datasets.iloc[0]['url'], sep=';', encoding='latin_1')

# %%
dipres_dic
# Out:
#                                         Dato  \
# 0                                        Año
# 1                                        Mes
# 2                                    Partida
# 3                             Nombre Partida
# 4                                   Capítulo
# 5                            Nombre Capítulo
# 6                                   Programa
# 7                            Nombre Programa
# 8                             Región Destino
# 9                              Nombre Región
# 10                         Provincia Destino
# 11                          Nombre Provincia
# 12                            Comuna Destino
# 13                             Nombre Comuna
# 14                                    Moneda
# 15                                Código Bip
# 16                           Nombre Proyecto
# 17  Suma de Monto Identificado Ley de Pptos.
# 18     Suma de Monto Devengado Ley de Pptos.
#
# ...

# %%
dipres_dic = pd.read_csv(dipres_datasets.iloc[-1]['url'], sep=';', encoding='latin_1')

# %%
dipres_dic
# Out:
#                    ï»¿Dato                                       DescripciÃ³n  \
# 0                     AÃ±o  AÃ±o al cual corresponde la Ley de Presupuesto...
# 1                      Mes  Mes del AÃ±o al cual se presentan acumulados l...
# 2                   Moneda  La Moneda en la cual se expresa la Ley de Pres...
# 3                  Partida                              CÃ³digo de la Partida
# 4           Nombre Partida                               Nombre de la Partida
# 5                CapÃ­tulo                              CÃ³digo del CapÃ­tulo
# 6         Nombre CapÃ­tulo                               Nombre del CapÃ­tulo
# 7                 Programa                               CÃ³digo del Programa
# 8          Nombre Programa                                Nombre del Programa
# 9               SubtÃ­tulo                             CÃ³digo del SubtÃ­tulo
# 10       Nombre SubtÃ­tulo                              Nombre del SubtÃ­tulo
# ...

# %% [markdown]
# # conclusion
# Los datos de la DIPRES solo consideran el año 2024 y su ejecucion particular del mes de mayo, lo cual provee poca informaciòn para hacer aálisis y conclusiones de las inversiones y sus pregrsiones. Por lo tanto continuaremos explorando otros data sets.
