# %% [raw]
# ---
# description: nbdev deployment of transparenta datos
# output-file: index.html
# title: transparencia-chile-2024
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# This file will become your README and also the index of your documentation.

# %% [markdown]
# ## Developer Guide

# %% [markdown]
# If you are new to using `nbdev` here are some useful pointers to get you started.

# %% [markdown]
# ### Install transparencia_chile_2024 in Development mode

# %% [markdown]
# ```sh
# # make sure transparencia_chile_2024 package is installed in development mode
# $ pip install -e .
#
# # make changes under nbs/ directory
# # ...
#
# # compile to have changes apply to transparencia_chile_2024
# $ nbdev_prepare
# ```

# %% [markdown]
# ## Usage

# %% [markdown]
# ### Installation

# %% [markdown]
# Install latest from the GitHub [repository][repo]:
#
# ```sh
# $ pip install git+https://github.com/FelipeCabelloE/transparencia-chile-2024.git
# ```
#
# or from [conda][conda]
#
# ```sh
# $ conda install -c FelipeCabelloE transparencia_chile_2024
# ```
#
# or from [pypi][pypi]
#
#
# ```sh
# $ pip install transparencia_chile_2024
# ```
#
#
# [repo]: https://github.com/FelipeCabelloE/transparencia-chile-2024
# [docs]: https://FelipeCabelloE.github.io/transparencia-chile-2024/
# [pypi]: https://pypi.org/project/transparencia-chile-2024/
# [conda]: https://anaconda.org/FelipeCabelloE/transparencia-chile-2024

# %% [markdown]
# ### Documentation

# %% [markdown]
# Documentation can be found hosted on this GitHub [repository][repo]'s [pages][docs]. Additionally you can find package manager specific guidelines on [conda][conda] and [pypi][pypi] respectively.
#
# [repo]: https://github.com/FelipeCabelloE/transparencia-chile-2024
# [docs]: https://FelipeCabelloE.github.io/transparencia-chile-2024/
# [pypi]: https://pypi.org/project/transparencia-chile-2024/
# [conda]: https://anaconda.org/FelipeCabelloE/transparencia-chile-2024

# %% [markdown]
# ## How to use

# %% [markdown]
# Fill me in please! Don't forget code examples:

# %%
1+1
# Out:
# 2
